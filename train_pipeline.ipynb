# %% [markdown]
# # 🏍️ Training Pipeline
# Run each step below to train your models. The results will be saved in the `outputs/` folder.

# %% [markdown]
# ### Step 1: Train Helmet Detector

# %%
from IPython.display import Image, display
import os# !python train/train_helmet.py

# %% [markdown]
# ### Step 2: Train License Plate Detector

# %%
# !python train/train_lp.py

# %% [markdown]
# ### Step 3: View Training Results
# This will show the training vs validation charts.

# %%
from IPython.display import Image, display
import os

# print("Helmet Training Chart:")
# if os.path.exists("outputs/training/helmet/results.png"):
#     display(Image(filename="outputs/training/helmet/results.png"))

print("\nLicense Plate Training Chart:")
if os.path.exists("outputs/training/lp/results.png"):
    display(Image(filename="outputs/training/lp/results.png"))
